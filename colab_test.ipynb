# %% [markdown]
# # Google Colab 接続テスト
#
# このノートブックを開いたら、以下の手順でColabに接続してください。
#
# 1. 右上の「カーネルの選択」をクリック
# 2. 「Colab」を選択
# 3. Googleアカウントでサインイン（求められた場合）
# 4. 以下のコードセルを実行してみてください

# %%
print("Hello from Google Colab!")
# !nvidia-smi
